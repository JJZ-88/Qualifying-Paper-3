# %%
import numpy as np
from matplotlib.pyplot import *

import logging
logging.disable(logging.WARNING)

import fun_mc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 7
#       4 import logging
#       5 logging.disable(logging.WARNING)
# ----> 7 import fun_mc
#
# ModuleNotFoundError: No module named 'fun_mc'
